# %%
# Imported Required Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# For Better Visuals
# %matplotlib inline
sns.set(style='whitegrid')

# %%
# encoding is used because exported CSV file from Power BI is not UTF-8 encoded
df = pd.read_csv('C:/Users/gandh/Downloads/HR_Data.csv', encoding='ISO-8859-1')
df.head()
# Out:
#    Employee ID          Name  Gender Department         Job Role  \
# 0       108201   Nitara Saha  Female      Sales  Sales Executive
# 1       137227  Kashvi Chana  Female      Sales  Sales Executive
# 2       399562   Lagan Bajwa  Female      Sales  Sales Executive
# 3       174649   Chirag Vasa  Female      Sales  Sales Executive
# 4       774763  Jhanvi Mahal  Female      Sales  Sales Executive
#
#    Performance Score  KPI Score Attendance (%)  Peer Rating  \
# 0                 77      70.93       9401.00%          4.2
# 1                 80      73.94       8352.00%          4.2
# 2                 72      74.95       8663.00%          3.0
# 3                 83      74.01       8197.00%          3.4
# 4                 87      75.97       8378.00%          3.1
#
#    Task Completion (%)  Work Hours Logged  Manager Feedback  Training Hours  \
# 0                96.69                 53               4.1               8
# 1                85.29                 43               3.7               4
# 2                88.10                 50               3.3              22
# 3                86.90                 38               3.5               8
# 4                87.26                 46               3.7               9
#
#   Promotion Eligibility PerformanceGroup TrainingGroup
# 0                    No           Medium           Low
# 1                    No           Medium           Low
# 2                    No           Medium        Medium
# 3                    No           Medium           Low
# 4                    No             High           Low

# %% [markdown]
# #### Basic Data Overview

# %%
print("Shape of the dataset:", df.shape)
# Out:
# Shape of the dataset: (5000, 16)

# %%
print("\nColumn names:\n", df.columns)
# Out:
# Column names:
#  Index(['Employee ID', 'Name', 'Gender', 'Department', 'Job Role',
#        'Performance Score', 'KPI Score', 'Attendance (%)', 'Peer Rating',
#        'Task Completion (%)', 'Work Hours Logged', 'Manager Feedback',
#        'Training Hours', 'Promotion Eligibility', 'PerformanceGroup',
#        'TrainingGroup'],
#       dtype='object')

# %%
print("\nData Types:\n", df.dtypes)
# Out:
# Data Types:
#  Employee ID                int64
# Name                      object
# Gender                    object
# Department                object
# Job Role                  object
# Performance Score          int64
# KPI Score                float64
# Attendance (%)            object
# Peer Rating              float64
# Task Completion (%)      float64
# Work Hours Logged          int64
# Manager Feedback         float64
# Training Hours             int64
# Promotion Eligibility     object
# PerformanceGroup          object
# TrainingGroup             object
# dtype: object

# %%
print("\nMissing values:\n", df.isnull().sum())
# Out:
# Missing values:
#  Employee ID              0
# Name                     0
# Gender                   0
# Department               0
# Job Role                 0
# Performance Score        0
# KPI Score                0
# Attendance (%)           0
# Peer Rating              0
# Task Completion (%)      0
# Work Hours Logged        0
# Manager Feedback         0
# Training Hours           0
# Promotion Eligibility    0
# PerformanceGroup         0
# TrainingGroup            0
# dtype: int64

# %% [markdown]
# #### Summary Statistics

# %%
 # Gives summary for both numerical and categorical
df.describe(include='all')
# Out:
#           Employee ID            Name Gender Department    Job Role  \
# count     5000.000000            5000   5000       5000        5000
# unique            NaN            4863      2          5          15
# top               NaN  Dhruv Sankaran   Male      Sales  Accountant
# freq              NaN               3   2504       1035         355
# mean    554223.243400             NaN    NaN        NaN         NaN
# std     261672.832133             NaN    NaN        NaN         NaN
# min     100021.000000             NaN    NaN        NaN         NaN
# 25%     324261.250000             NaN    NaN        NaN         NaN
# 50%     556827.500000             NaN    NaN        NaN         NaN
# 75%     780774.500000             NaN    NaN        NaN         NaN
# max     999957.000000             NaN    NaN        NaN         NaN
#
#         Performance Score    KPI Score Attendance (%)  Peer Rating  \
# count         5000.000000  5000.000000           5000  5000.000000
# unique                NaN          NaN           2172          NaN
# top                   NaN          NaN       8085.00%          NaN
# freq                  NaN          NaN              7          NaN
# mean            74.779400    77.384996            NaN     4.000080
# std             14.666211    10.157152            NaN     0.580889
# min             50.000000    60.010000            NaN     3.000000
# 25%             62.000000    68.327500            NaN     3.500000
# 50%             75.000000    77.340000            NaN     4.000000
# 75%             87.000000    86.050000            NaN     4.500000
# max            100.000000    94.990000            NaN     5.000000
#
#         Task Completion (%)  Work Hours Logged  Manager Feedback  \
# count           5000.000000        5000.000000       5000.000000
# unique                  NaN                NaN               NaN
# top                     NaN                NaN               NaN
# freq                    NaN                NaN               NaN
# mean              84.978782          44.929800          4.001500
# std                8.696399           5.961106          0.579257
# min               70.010000          35.000000          3.000000
# 25%               77.317500          40.000000          3.500000
# 50%               85.125000          45.000000          4.000000
# 75%               92.472500          50.000000          4.500000
# max              100.000000          55.000000          5.000000
#
#         Training Hours Promotion Eligibility PerformanceGroup TrainingGroup
# count      5000.000000                  5000             5000          5000
# unique             NaN                     2                3             2
# top                NaN                    No           Medium           Low
# freq               NaN                  4305             2465          3219
# mean         14.876800                   NaN              NaN           NaN
# std           9.005523                   NaN              NaN           NaN
# min           0.000000                   NaN              NaN           NaN
# 25%           7.000000                   NaN              NaN           NaN
# 50%          15.000000                   NaN              NaN           NaN
# 75%          23.000000                   NaN              NaN           NaN
# max          30.000000                   NaN              NaN           NaN

# %% [markdown]
# #### Data Cleaning

# %%
# Remove duplicate rows
df.drop_duplicates(inplace=True)

# Clean 'Attendance (%)' column: remove %, convert to float
df['Attendance (%)'] = df['Attendance (%)'].astype(str).str.replace('%', '', regex=False)
df['Attendance (%)'] = pd.to_numeric(df['Attendance (%)'], errors='coerce')

# Convert 'Task Completion (%)' to float (already numeric, so wrap in to_numeric)
df['Task Completion (%)'] = pd.to_numeric(df['Task Completion (%)'], errors='coerce')

# Convert 'KPI Score' to numeric and fill missing with mean
df['KPI Score'] = pd.to_numeric(df['KPI Score'], errors='coerce')
df['KPI Score'] = df['KPI Score'].fillna(df['KPI Score'].mean())

# %%
print(df['Attendance (%)'].dtype)
# Out:
# float64

# %% [markdown]
# #### Descriptive Statistics

# %%
# Summary statistics for numeric columns
df.describe()
# Out:
#          Employee ID  Performance Score    KPI Score  Attendance (%)  \
# count    5000.000000        5000.000000  5000.000000     5000.000000
# mean   554223.243400          74.779400    77.384996     8746.672000
# std    261672.832133          14.666211    10.157152      723.082713
# min    100021.000000          50.000000    60.010000     7501.000000
# 25%    324261.250000          62.000000    68.327500     8113.000000
# 50%    556827.500000          75.000000    77.340000     8741.500000
# 75%    780774.500000          87.000000    86.050000     9375.250000
# max    999957.000000         100.000000    94.990000    10000.000000
#
#        Peer Rating  Task Completion (%)  Work Hours Logged  Manager Feedback  \
# count  5000.000000          5000.000000        5000.000000       5000.000000
# mean      4.000080            84.978782          44.929800          4.001500
# std       0.580889             8.696399           5.961106          0.579257
# min       3.000000            70.010000          35.000000          3.000000
# 25%       3.500000            77.317500          40.000000          3.500000
# 50%       4.000000            85.125000          45.000000          4.000000
# 75%       4.500000            92.472500          50.000000          4.500000
# max       5.000000           100.000000          55.000000          5.000000
#
#        Training Hours
# count     5000.000000
# mean        14.876800
# std          9.005523
# min          0.000000
# 25%          7.000000
# 50%         15.000000
# 75%         23.000000
# max         30.000000

# %% [markdown]
# #### --> Distribution of Performance Score(Distribution Plot)

# %%
# Understand how performance scores are distributed among employees

plt.figure(figsize=(6,4))
sns.histplot(df['Performance Score'], bins=10, kde=True)
plt.title('Distribution of Performance Score')
plt.xlabel('Performance Score')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### --> Employee Count by Department(Count Plot)

# %%
# It shows how employees are distributed across departments
plt.figure(figsize=(8,5))
sns.countplot(x='Department', data=df, order=df['Department'].value_counts().index)
plt.title('Employee Count by Department')
plt.xlabel('Department')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### --> KPI Score by Department (Boxplot)

# %%
# To understand variation in KPI score across departments
plt.figure(figsize=(10,5))
sns.boxplot(x='Department', y='KPI Score', data=df)
plt.title('KPI Score by Department')
plt.xlabel('Department')
plt.ylabel('KPI Score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### --> Correlation Heatmap

# %%
# To Check which numerical features are correlated.

# Select only numeric columns
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

plt.figure(figsize=(10,6))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Numeric Features')
plt.show()

# %% [markdown]
# ### 🔍 Missing Values Check

# %%
print("\nMissing Values:\n", df.isnull().sum())
sns.heatmap(df.isnull(), cbar=False, cmap="Blues_r")
plt.title("Missing Values Heatmap", fontsize=14)
plt.show()
# Out:
# Missing Values:
#  Employee ID              0
# Name                     0
# Gender                   0
# Department               0
# Job Role                 0
# Performance Score        0
# KPI Score                0
# Attendance (%)           0
# Peer Rating              0
# Task Completion (%)      0
# Work Hours Logged        0
# Manager Feedback         0
# Training Hours           0
# Promotion Eligibility    0
# PerformanceGroup         0
# TrainingGroup            0
# dtype: int64

# %% [markdown]
# ### 🔁 Duplicate Rows Check

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %% [markdown]
# ### 📊 Summary Statistics

# %%
df.describe(include='all')
# Out:
#           Employee ID            Name Gender Department    Job Role  \
# count     5000.000000            5000   5000       5000        5000
# unique            NaN            4863      2          5          15
# top               NaN  Dhruv Sankaran   Male      Sales  Accountant
# freq              NaN               3   2504       1035         355
# mean    554223.243400             NaN    NaN        NaN         NaN
# std     261672.832133             NaN    NaN        NaN         NaN
# min     100021.000000             NaN    NaN        NaN         NaN
# 25%     324261.250000             NaN    NaN        NaN         NaN
# 50%     556827.500000             NaN    NaN        NaN         NaN
# 75%     780774.500000             NaN    NaN        NaN         NaN
# max     999957.000000             NaN    NaN        NaN         NaN
#
#         Performance Score    KPI Score Attendance (%)  Peer Rating  \
# count         5000.000000  5000.000000           5000  5000.000000
# unique                NaN          NaN           2172          NaN
# top                   NaN          NaN       8085.00%          NaN
# freq                  NaN          NaN              7          NaN
# mean            74.779400    77.384996            NaN     4.000080
# std             14.666211    10.157152            NaN     0.580889
# min             50.000000    60.010000            NaN     3.000000
# 25%             62.000000    68.327500            NaN     3.500000
# 50%             75.000000    77.340000            NaN     4.000000
# 75%             87.000000    86.050000            NaN     4.500000
# max            100.000000    94.990000            NaN     5.000000
#
#         Task Completion (%)  Work Hours Logged  Manager Feedback  \
# count           5000.000000        5000.000000       5000.000000
# unique                  NaN                NaN               NaN
# top                     NaN                NaN               NaN
# freq                    NaN                NaN               NaN
# mean              84.978782          44.929800          4.001500
# std                8.696399           5.961106          0.579257
# min               70.010000          35.000000          3.000000
# 25%               77.317500          40.000000          3.500000
# 50%               85.125000          45.000000          4.000000
# 75%               92.472500          50.000000          4.500000
# max              100.000000          55.000000          5.000000
#
#         Training Hours Promotion Eligibility PerformanceGroup TrainingGroup
# count      5000.000000                  5000             5000          5000
# unique             NaN                     2                3             2
# top                NaN                    No           Medium           Low
# freq               NaN                  4305             2465          3219
# mean         14.876800                   NaN              NaN           NaN
# std           9.005523                   NaN              NaN           NaN
# min           0.000000                   NaN              NaN           NaN
# 25%           7.000000                   NaN              NaN           NaN
# 50%          15.000000                   NaN              NaN           NaN
# 75%          23.000000                   NaN              NaN           NaN
# max          30.000000                   NaN              NaN           NaN

# %% [markdown]
# ### 📋 Value Counts of Categorical Features

# %%
categorical_cols = df.select_dtypes(include='object').columns
for col in categorical_cols:
    print(f"\nValue counts for '{col}':\n", df[col].value_counts())
# Out:
# Value counts for 'Name':
#  Name
# Dhruv Sankaran       3
# Tara Sarma           2
# Bhamini Shankar      2
# Dhruv Bali           2
# Ojas Sunder          2
#                     ..
# Jivin Dash           1
# Miraan Shetty        1
# Hazel Ram            1
# Amira Swaminathan    1
# Nehmat Ahluwalia     1
# Name: count, Length: 4863, dtype: int64
#
# Value counts for 'Gender':
#  Gender
# Male      2504
# Female    2496
# Name: count, dtype: int64
#
# Value counts for 'Department':
#  Department
# Sales        1035
# Finance      1016
# HR           1010
# IT            974
# Marketing     965
# Name: count, dtype: int64
#
# Value counts for 'Job Role':
#  Job Role
# Accountant                  355
# Business Development        348
# Cybersecurity Specialist    345
# Employee Relations          344
# Sales Executive             344
# Account Manager             343
# Recruitment Specialist      341
# Auditor                     333
# Marketing Executive         330
# Financial Analyst           328
# SEO Specialist              326
# HR Manager                  325
# Software Engineer           318
# Data Analyst                311
# Content Strategist          309
# Name: count, dtype: int64
#
# Value counts for 'Attendance (%)':
#  Attendance (%)
# 8085.00%    7
# 8018.00%    7
# 7639.00%    7
# 7842.00%    7
# 7849.00%    7
#            ..
# 9468.00%    1
# 7944.00%    1
# 9626.00%    1
# 9278.00%    1
# 9720.00%    1
# Name: count, Length: 2172, dtype: int64
#
# Value counts for 'Promotion Eligibility':
#  Promotion Eligibility
# No     4305
# Yes     695
# Name: count, dtype: int64
#
# Value counts for 'PerformanceGroup':
#  PerformanceGroup
# Medium    2465
# High      1537
# Low        998
# Name: count, dtype: int64
#
# Value counts for 'TrainingGroup':
#  TrainingGroup
# Low       3219
# Medium    1781
# Name: count, dtype: int64

# %% [markdown]
# ### 🔗 Correlation Heatmap

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# ### No.of Employees Eligible For Promotion

# %%
print(df.columns)
sns.countplot(x='Promotion Eligibility', data=df)
plt.title('Promotion Eligibility Count')
plt.show()

# %% [markdown]
# #### Count the number of employees in each department:

# %%
sns.countplot(x='Department', data=df)
plt.title('Department-wise Employee Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 📈 Feature Distributions

# %%
for col in df.select_dtypes(include='number').columns:
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %% [markdown]
# ###  Grouped Statistics

# %%
grouped_df = df.groupby('Department')['KPI Score'].mean().reset_index()
print(grouped_df)
# Out:
#   Department  KPI Score
# 0    Finance  77.392628
# 1         HR  77.664614
# 2         IT  77.445390
# 3  Marketing  76.904415
# 4      Sales  77.495884

# %%
df.groupby('Department')['Performance Score'].mean().plot(kind='bar', color='skyblue')
plt.title('Avg Performance Score by Department')
plt.ylabel('Performance Score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 🧪 Outlier Detection Using Boxplots

# %%
for col in df.select_dtypes(include='number').columns:
    sns.boxplot(y=col, data=df)
    plt.title(f'Boxplot of {col}')
    plt.show()
